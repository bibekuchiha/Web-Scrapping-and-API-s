# %%
import pandas as pd

# %%
json_data = pd.read_json('all_quotes.json')

# %%
json_data.head()
# Out:
#                                               quotes  \
# 0  \n      “I'm selfish, impatient and a little i...
# 1  \n      “Be yourself; everyone else is already...
# 2  \n      “Two things are infinite: the universe...
# 3       \n      “So many books, so little time.”\n
# 4  \n      “A room without books is like a body w...
#
#                             author  \
# 0         \n    Marilyn Monroe\n
# 1            \n    Oscar Wilde\n
# 2        \n    Albert Einstein\n
# 3            \n    Frank Zappa\n
# 4  \n    Marcus Tullius Cicero\n
#
#                                                 tags         likes
# 0  [attributed-no-source, best, life, love, mista...  153615 likes
# 1  [attributed-no-source, be-yourself, honesty, i...  153449 likes
# 2  [attributed-no-source, human-nature, humor, in...  135213 likes
# 3                                     [books, humor]  131745 likes
# 4        [attributed-no-source, books, simile, soul]  123154 likes

# %%
json_data
# Out:
#                                                  quotes  \
# 0     \n      “I'm selfish, impatient and a little i...
# 1     \n      “Be yourself; everyone else is already...
# 2     \n      “Two things are infinite: the universe...
# 3          \n      “So many books, so little time.”\n
# 4     \n      “A room without books is like a body w...
# ...                                                 ...
# 2995  \n      “Winter is the time for comfort, for g...
# 2996  \n      “The problem with doing nothing is not...
# 2997  \n      “What is honor compared to a woman's l...
# 2998  \n      “No one is useless in this world who l...
# 2999  \n      “It's the mortal cup Jace, not the mor...
#
#                                author  \
# 0            \n    Marilyn Monroe\n
# 1               \n    Oscar Wilde\n
# 2           \n    Albert Einstein\n
# 3               \n    Frank Zappa\n
# 4     \n    Marcus Tullius Cicero\n
# ...                               ...
# ...

# %%
print(json_data['quotes'][90])
# Out:
#       “We read to know we're not alone.”
