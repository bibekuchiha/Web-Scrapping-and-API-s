# %%
import pandas as pd

# %%
json_data = pd.read_json('quotes.json')

# %%
json_data.head()
# Out:
#                                               quotes  \
# 0  \n      “I'm selfish, impatient and a little i...
# 1  \n      “Be yourself; everyone else is already...
# 2  \n      “Two things are infinite: the universe...
# 3       \n      “So many books, so little time.”\n
# 4  \n      “A room without books is like a body w...
#
#                             author  \
# 0         \n    Marilyn Monroe\n
# 1            \n    Oscar Wilde\n
# 2        \n    Albert Einstein\n
# 3            \n    Frank Zappa\n
# 4  \n    Marcus Tullius Cicero\n
#
#                                                 tags         likes
# 0  [attributed-no-source, best, life, love, mista...  153615 likes
# 1  [attributed-no-source, be-yourself, honesty, i...  153447 likes
# 2  [attributed-no-source, human-nature, humor, in...  135213 likes
# 3                                     [books, humor]  131745 likes
# 4        [attributed-no-source, books, simile, soul]  123154 likes

# %%
json_data
# Out:
#                                                quotes  \
# 0   \n      “I'm selfish, impatient and a little i...
# 1   \n      “Be yourself; everyone else is already...
# 2   \n      “Two things are infinite: the universe...
# 3        \n      “So many books, so little time.”\n
# 4   \n      “A room without books is like a body w...
# 5   \n      “Be who you are and say what you feel,...
# 6   \n      “You've gotta dance like there's nobod...
# 7   \n      “You know you're in love when you can'...
# 8   \n      “You only live once, but if you do it ...
# 9   \n      “Be the change that you wish to see in...
# 10  \n      “In three words I can sum up everythin...
# 11  \n      “If you want to know what a man's like...
# 12  \n      “Don’t walk in front of me… I may not ...
# 13  \n      “No one can make you feel inferior wit...
# 14  \n      “If you tell the truth, you don't have...
# 15  \n      “Friendship ... is born at the moment ...
# ...

# %%
print(json_data['quotes'][0])
# Out:
#       “I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”
